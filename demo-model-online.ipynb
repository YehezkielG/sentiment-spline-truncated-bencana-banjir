# %%
from transformers import pipeline

model_id = "zekiell/indobert-tiktok-political-sentiment"

nlp = pipeline("text-classification", model=model_id)

result = nlp("zekiell adalah orang yang sangat baik hati dan suka menolong sesama.")
print(result)
# Out:
# Device set to use cpu
# [{'label': 'Positive', 'score': 0.9810755252838135}]
