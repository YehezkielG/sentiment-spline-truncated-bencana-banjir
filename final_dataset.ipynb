# %%
import pandas as pd
df = pd.read_csv('data/tiktok_comments_final.csv')
df.nunique().sort_values(ascending=False)
# Out:
# text          4223
# createTime    4115
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7993 entries, 0 to 7992
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   text        7958 non-null   object
#  1   createTime  7993 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 125.0+ KB

# %%
df2 = pd.read_csv('data/data unmerge/tiktok_comments5.csv')
df2.nunique().sort_values(ascending=False)
# Out:
# cid                  4000
# uniqueId             3968
# uid                  3968
# createTimeISO        3938
# createTime           3938
# avatarThumbnail      3884
# text                 3819
# diggCount             147
# replyCommentTotal      61
# detailedMentions       35
# mentions               35
# likedByAuthor           2
# videoWebUrl             1
# input                   1
# submittedVideoUrl       1
# pinnedByAuthor          1
# repliesToId             0
# dtype: int64

# %%
merged_df = pd.concat([df, df2], ignore_index=True)
merged_df = merged_df.drop_duplicates(subset=["text","createTime"], keep="first").reset_index(drop=True)
merged_df
# Out:
#                                                    text  createTime  \
# 0                                               gibran:  1764933105
# 1     ini emg harusnya ganti rakyat sih. bgnian emg ...  1764928295
# 2                wapres aja gak pakek rompi anti peluru  1764922201
# 3         di indo doang presiden n wapres di hujat wkwk  1764925978
# 4     di X parah bett anjir komenannya, merinding la...  1764922173
# ...                                                 ...         ...
# 4399  WOY TERMUL INFO LOKER DONG JADI TERMUL\nMAYAN ...  1764985616
# 4400                                                  🥺  1764985466
# 4401                                                 👍👍  1764985270
# 4402                                                🔥🔥🔥  1764984978
# 4403                                                NaN  1765082278
#
#                                             videoWebUrl  \
# 0                                                   NaN
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4404 entries, 0 to 4403
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               4369 non-null   object
#  1   createTime         4404 non-null   int64
#  2   videoWebUrl        1 non-null      object
#  3   submittedVideoUrl  1 non-null      object
#  4   input              1 non-null      object
#  5   cid                1 non-null      float64
#  6   createTimeISO      1 non-null      object
#  7   diggCount          1 non-null      float64
#  8   likedByAuthor      1 non-null      object
#  9   pinnedByAuthor     1 non-null      object
#  10  repliesToId        0 non-null      float64
#  11  replyCommentTotal  1 non-null      float64
#  12  uid                1 non-null      float64
#  13  uniqueId           1 non-null      object
#  14  avatarThumbnail    1 non-null      object
#  15  mentions           1 non-null      object
# ...

# %%
merged_df[["text","createTime"]].to_csv('data/tiktok_comments_final.csv', index=False)
