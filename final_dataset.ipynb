# %%
import pandas as pd
df = pd.read_csv('data/tiktok_comments_final.csv')
df.nunique().sort_values(ascending=False)
# Out:
# cid                  4177
# uniqueId             4158
# uid                  4144
# createTimeISO        4110
# createTime           4110
# avatarThumbnail      4076
# text                 3993
# diggCount             149
# replyCommentTotal      65
# detailedMentions       35
# mentions               35
# likedByAuthor           2
# videoWebUrl             1
# input                   1
# submittedVideoUrl       1
# pinnedByAuthor          1
# repliesToId             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoWebUrl        4193 non-null   object
#  1   submittedVideoUrl  4193 non-null   object
#  2   input              4193 non-null   object
#  3   cid                4192 non-null   float64
#  4   createTime         4193 non-null   int64
#  5   createTimeISO      4193 non-null   object
#  6   text               4155 non-null   object
#  7   diggCount          4193 non-null   int64
#  8   likedByAuthor      4193 non-null   bool
#  9   pinnedByAuthor     4193 non-null   bool
#  10  repliesToId        0 non-null      float64
#  11  replyCommentTotal  4193 non-null   int64
#  12  uid                4193 non-null   int64
#  13  uniqueId           4193 non-null   object
#  14  avatarThumbnail    4193 non-null   object
#  15  mentions           4193 non-null   object
#  16  detailedMentions   4193 non-null   object
# dtypes: bool(2), float64(2), int64(4), object(9)
# memory usage: 499.7+ KB

# %%
df2 = pd.read_csv('data/data unmerge/hasil_scraping3.csv')
df2.nunique().sort_values(ascending=False)
# Out:
# cid                  4000
# uniqueId             3968
# uid                  3968
# createTimeISO        3935
# createTime           3935
# avatarThumbnail      3882
# text                 3820
# diggCount             144
# replyCommentTotal      59
# detailedMentions       35
# mentions               35
# likedByAuthor           2
# videoWebUrl             1
# input                   1
# submittedVideoUrl       1
# pinnedByAuthor          1
# repliesToId             0
# dtype: int64

# %%
merged_df = pd.concat([df, df2], ignore_index=True)
merged_df = merged_df.drop_duplicates(subset=["uniqueId", "text"], keep="first").reset_index(drop=True)
merged_df
# Out:
#                                             videoWebUrl  \
# 0     https://www.tiktok.com/@antaranews/video/75802...
# 1     https://www.tiktok.com/@antaranews/video/75802...
# 2     https://www.tiktok.com/@antaranews/video/75802...
# 3     https://www.tiktok.com/@antaranews/video/75802...
# 4     https://www.tiktok.com/@antaranews/video/75802...
# ...                                                 ...
# 4188  https://www.tiktok.com/@antaranews/video/75802...
# 4189  https://www.tiktok.com/@antaranews/video/75802...
# 4190  https://www.tiktok.com/@antaranews/video/75802...
# 4191  https://www.tiktok.com/@antaranews/video/75802...
# 4192  https://www.tiktok.com/@antaranews/video/75802...
#
#                                       submittedVideoUrl  \
# 0     https://www.tiktok.com/@antaranews/video/75802...
# 1             False           False          NaN                283
# 2             False           False          NaN                439
# 3             False           False          NaN                452
# 4             False           False          NaN                800
# ...             ...             ...          ...                ...
# 4188          False           False          NaN                  0
# 4189          False           False          NaN                  0
# 4190          False           False          NaN                  0
# 4191          False           False          NaN                  0
# 4192          False           False          NaN                  0
#
#                       uid            uniqueId  \
# 0     7232671917768803330         momoiieeeee
# 1     6874043506123637761            caprcgrl
# 2     6968002027155932162  nama.saya111111111
# 3     7348661950966023173        an0ther.ngel
# 4     7117624082120918043       meloddyyyyyy_
# ...                   ...                 ...
# 4188  6733828697662833666            raaahmaw
# 4189  7542045756237071381         anonim01376
# 4190  6782536808044823554           evvanitae
# 4191  7104546523975025666        tinharyati16
# 4192  6889064357985485826         ds.chanel21
#
#                                         avatarThumbnail mentions  \
# 0     https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 1     https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 2     https://p16-common-sign.tiktokcdn-us.com/tos-m...       []
# 3     https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 4     https://p16-common-sign.tiktokcdn-us.com/tos-m...       []
# ...                                                 ...      ...
# 4188  https://p16-sign-sg.tiktokcdn.com/tos-alisg-av...       []
# 4189  https://p16-common-sign.tiktokcdn-us.com/tos-a...       []
# 4190  https://p16-common-sign.tiktokcdn-us.com/tos-m...       []
# 4191  https://p16-common-sign.tiktokcdn-us.com/tos-u...       []
# 4192  https://p16-sign-va.tiktokcdn.com/tos-maliva-a...       []
#
#      detailedMentions
# 0                  []
# 1                  []
# 2                  []
# 3                  []
# 4                  []
# ...               ...
# 4188               []
# 4189               []
# 4190               []
# 4191               []
# 4192               []
#
# [4193 rows x 17 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoWebUrl        4193 non-null   object
#  1   submittedVideoUrl  4193 non-null   object
#  2   input              4193 non-null   object
#  3   cid                4192 non-null   float64
#  4   createTime         4193 non-null   int64
#  5   createTimeISO      4193 non-null   object
#  6   text               4155 non-null   object
#  7   diggCount          4193 non-null   int64
#  8   likedByAuthor      4193 non-null   bool
#  9   pinnedByAuthor     4193 non-null   bool
#  10  repliesToId        0 non-null      float64
#  11  replyCommentTotal  4193 non-null   int64
#  12  uid                4193 non-null   int64
#  13  uniqueId           4193 non-null   object
#  14  avatarThumbnail    4193 non-null   object
#  15  mentions           4193 non-null   object
#  16  detailedMentions   4193 non-null   object
# dtypes: bool(2), float64(2), int64(4), object(9)
# memory usage: 499.7+ KB

# %%
merged_df[["text","createTime"]].to_csv('data/tiktok_comments_final.csv', index=False)
