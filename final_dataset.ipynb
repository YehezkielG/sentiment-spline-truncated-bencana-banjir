# %%
import pandas as pd
df = pd.read_csv('data/tiktok_comments_final.csv')
df.nunique().sort_values(ascending=False)
# Out:
# cid                  4133
# avatarThumbnail      4112
# uniqueId             4109
# uid                  4100
# createTimeISO        4068
# createTime           4068
# text                 4041
# diggCount             150
# replyCommentTotal      64
# detailedMentions       35
# mentions               35
# likedByAuthor           2
# videoWebUrl             1
# input                   1
# submittedVideoUrl       1
# pinnedByAuthor          1
# repliesToId             0
# dtype: int64

# %%
df2 = pd.read_csv('data/hasil_scraping_after_shufle_2025-12-06.csv')
df2.nunique().sort_values(ascending=False)
# Out:
# cid                  3870
# uniqueId             3840
# uid                  3840
# createTimeISO        3816
# createTime           3816
# avatarThumbnail      3760
# text                 3699
# diggCount             143
# replyCommentTotal      62
# detailedMentions       33
# mentions               33
# likedByAuthor           2
# videoWebUrl             1
# input                   1
# submittedVideoUrl       1
# pinnedByAuthor          1
# repliesToId             0
# dtype: int64

# %%
merged_df = pd.concat([df, df2], ignore_index=True)
merged_df = merged_df.drop_duplicates(subset=["uniqueId", "text"], keep="first").reset_index(drop=True)
merged_df
# Out:
#                                             videoWebUrl  \
# 0     https://www.tiktok.com/@antaranews/video/75802...
# 1     https://www.tiktok.com/@antaranews/video/75802...
# 2     https://www.tiktok.com/@antaranews/video/75802...
# 3     https://www.tiktok.com/@antaranews/video/75802...
# 4     https://www.tiktok.com/@antaranews/video/75802...
# ...                                                 ...
# 4269  https://www.tiktok.com/@antaranews/video/75802...
# 4270  https://www.tiktok.com/@antaranews/video/75802...
# 4271  https://www.tiktok.com/@antaranews/video/75802...
# 4272  https://www.tiktok.com/@antaranews/video/75802...
# 4273  https://www.tiktok.com/@antaranews/video/75802...
#
#                                       submittedVideoUrl  \
# 0     https://www.tiktok.com/@antaranews/video/75802...
# 1     https://www.tiktok.com/@antaranews/video/75802...
# 2     https://www.tiktok.com/@antaranews/video/75802...
# 3     https://www.tiktok.com/@antaranews/video/75802...
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4274 entries, 0 to 4273
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   videoWebUrl        4274 non-null   object
#  1   submittedVideoUrl  4274 non-null   object
#  2   input              4274 non-null   object
#  3   cid                4184 non-null   float64
#  4   createTime         4274 non-null   int64
#  5   createTimeISO      4274 non-null   object
#  6   text               4236 non-null   object
#  7   diggCount          4274 non-null   int64
#  8   likedByAuthor      4274 non-null   bool
#  9   pinnedByAuthor     4274 non-null   bool
#  10  repliesToId        0 non-null      float64
#  11  replyCommentTotal  4274 non-null   int64
#  12  uid                4274 non-null   int64
#  13  uniqueId           4274 non-null   object
#  14  avatarThumbnail    4274 non-null   object
#  15  mentions           4274 non-null   object
# ...

# %%
merged_df.to_csv('data/tiktok_comments_final.csv', index=False)

# %%
d = {
    "a":["A","A","A"],
    "b":[1,1,1],
}

df_test = pd.DataFrame(d)
df_test = df_test.drop_duplicates()
df_test
# Out:
#    a  b
# 0  A  1
